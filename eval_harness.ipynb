# %% [markdown]
# <a href="https://colab.research.google.com/github/katherineworden/cs224N/blob/main/eval_harness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Remove the existing directory if it exists
# !rm -rf lm-evaluation-harness

# Clone the repository
# !git clone https://github.com/EleutherAI/lm-evaluation-harness

# Navigate into the directory and install the package
# !pip install -e ./lm-evaluation-harness

# Navigate back to the root directory (optional, but good practice)
# !cd ..
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 34590, done.
# remote: Counting objects: 100% (679/679), done.
# remote: Compressing objects: 100% (429/429), done.
# remote: Total 34590 (delta 367), reused 415 (delta 246), pack-reused 33911
# Receiving objects: 100% (34590/34590), 23.52 MiB | 13.88 MiB/s, done.
# Resolving deltas: 100% (24102/24102), done.
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 47.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 35.4 MB/s eta 0:00:00
# ...

# %%
# !lm_eval --model hf \
    --tasks hellaswag \
    --model_args pretrained=ksw1/final-sleeper-agent-quant,parallelize=True \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-06-06 01:50:01.409840: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-06 01:50:01.460184: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 01:50:01.460230: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 01:50:01.461723: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
